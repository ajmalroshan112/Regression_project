# %% [markdown]
# <a href="https://colab.research.google.com/github/ajmalroshan112/Regression_project/blob/main/Regression_Car_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
from IPython.display import display
display(Image(filename='/content/images (2).jpeg',width=700,height=350))

# %%
# import necessary libraries
import numpy as np
import pandas as pd
df=pd.read_csv('/content/train-data.csv')
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
# fst 5
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
df.tail()
# Out:
#       Unnamed: 0                      Name   Location  Year  \
# 6014        6014          Maruti Swift VDI      Delhi  2014
# 6015        6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015
# 6016        6016     Mahindra Xylo D4 BSIV     Jaipur  2012
# 6017        6017        Maruti Wagon R VXI    Kolkata  2013
# 6018        6018     Chevrolet Beat Diesel  Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine     Power  Seats  New_Price  Price
# 6014  1248 CC    74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC    71 bhp    5.0        NaN   4.00
# 6016  2498 CC   112 bhp    8.0        NaN   2.90
# 6017   998 CC  67.1 bhp    5.0        NaN   2.65
# 6018   936 CC  57.6 bhp    5.0        NaN   2.50

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
name=df['Name'].value_counts()
name
# Out:
# Name
# Mahindra XUV500 W8 2WD           49
# Maruti Swift VDI                 45
# Honda City 1.5 S MT              34
# Maruti Swift Dzire VDI           34
# Maruti Swift VDI BSIV            31
#                                  ..
# Ford Fiesta Titanium 1.5 TDCi     1
# Mahindra Scorpio S10 AT 4WD       1
# Hyundai i20 1.2 Era               1
# Toyota Camry W4 (AT)              1
# Mahindra Xylo D4 BSIV             1
# Name: count, Length: 1878, dtype: int64

# %%
# each values counts
location=df['Location'].value_counts()
location
# Out:
# Location
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: count, dtype: int64

# %%
# visualisation
import matplotlib.pyplot as plt
location.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('locationcount graph',color='blue',fontsize=26)
# Out:
# Text(0.5, 1.0, 'locationcount graph')

# %%
fuel=df['Fuel_Type'].value_counts()
fuel
# Out:
# Fuel_Type
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
fuel.plot(kind='barh',color='green',fontsize=15)
plt.title('fuelcount graph',color='blue',fontsize=26)
# Out:
# Text(0.5, 1.0, 'fuelcount graph')

# %%
Transmission=df['Transmission'].value_counts()
Transmission
# Out:
# Transmission
# Manual       4299
# Automatic    1720
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
Transmission.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('Trasnsmissioncount graph',color='red',fontsize=26)
# Out:
# Text(0.5, 1.0, 'Trasnsmissioncount graph')

# %%
owner=df['Owner_Type'].value_counts()
owner
# Out:
# Owner_Type
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
owner.plot(kind='barh',color='red',fontsize=15)
plt.title('Ownercount graph',color='red',fontsize=26)
# Out:
# Text(0.5, 1.0, 'Ownercount graph')

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
# encoding get dummy encoding
df1=pd.get_dummies(df[['Location','Fuel_Type','Transmission','Owner_Type']],drop_first=True)
df1
# Out:
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 0                  False             False                False
# 1                  False             False                False
# 2                  False              True                False
# 3                  False              True                False
# 4                  False             False                 True
# ...                  ...               ...                  ...
# 6014               False             False                False
# 6015               False             False                False
# 6016               False             False                False
# 6017               False             False                False
# 6018               False             False                False
#
#       Location_Delhi  Location_Hyderabad  Location_Jaipur  Location_Kochi  \
# 0              False               False            False           False
# 1              False               False            False           False
# 2              False               False            False           False
# 3              False               False            False           False
# 4              False               False            False           False
# ...              ...                 ...              ...             ...
# 6014            True               False            False           False
# 6015           False               False             True           False
# 6016           False               False             True           False
# 6017           False               False            False           False
# 6018           False                True            False           False
#
#       Location_Kolkata  Location_Mumbai  Location_Pune  Fuel_Type_Diesel  \
# 0                False             True          False             False
# 1                False            False           True              True
# 2                False            False          False             False
# 3                False            False          False              True
# 4                False            False          False              True
# ...                ...              ...            ...               ...
# 6014             False            False          False              True
# 6015             False            False          False              True
# 6016             False            False          False              True
# 6017              True            False          False             False
# 6018             False            False          False              True
#
#       Fuel_Type_Electric  Fuel_Type_LPG  Fuel_Type_Petrol  \
# 0                  False          False             False
# 1                  False          False             False
# 2                  False          False              True
# 3                  False          False             False
# 4                  False          False             False
# ...                  ...            ...               ...
# 6014               False          False             False
# 6015               False          False             False
# 6016               False          False             False
# 6017               False          False              True
# 6018               False          False             False
#
#       Transmission_Manual  Owner_Type_Fourth & Above  Owner_Type_Second  \
# 0                    True                      False              False
# 1                    True                      False              False
# 2                    True                      False              False
# 3                    True                      False              False
# 4                   False                      False               True
# ...                   ...                        ...                ...
# 6014                 True                      False              False
# 6015                 True                      False              False
# 6016                 True                      False               True
# 6017                 True                      False              False
# 6018                 True                      False              False
#
#       Owner_Type_Third
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 6014             False
# 6015             False
# 6016             False
# 6017             False
# 6018             False
#
# [6019 rows x 18 columns]

# %%
# concatination
dfe=pd.concat([df,df1],axis=1)
dfe
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine  ... Location_Mumbai  Location_Pune Fuel_Type_Diesel  \
# 0      998 CC  ...            True          False            False
# 1     1582 CC  ...           False           True             True
# 2     1199 CC  ...           False          False            False
# 3     1248 CC  ...           False          False             True
# 4     1968 CC  ...           False          False             True
# ...       ...  ...             ...            ...              ...
# 6014  1248 CC  ...           False          False             True
# 6015  1120 CC  ...           False          False             True
# 6016  2498 CC  ...           False          False             True
# 6017   998 CC  ...           False          False            False
# 6018   936 CC  ...           False          False             True
#
#       Fuel_Type_Electric  Fuel_Type_LPG  Fuel_Type_Petrol  \
# 0                  False          False             False
# 1                  False          False             False
# 2                  False          False              True
# 3                  False          False             False
# 4                  False          False             False
# ...                  ...            ...               ...
# 6014               False          False             False
# 6015               False          False             False
# 6016               False          False             False
# 6017               False          False              True
# 6018               False          False             False
#
#       Transmission_Manual  Owner_Type_Fourth & Above  Owner_Type_Second  \
# 0                    True                      False              False
# 1                    True                      False              False
# 2                    True                      False              False
# 3                    True                      False              False
# 4                   False                      False               True
# ...                   ...                        ...                ...
# 6014                 True                      False              False
# 6015                 True                      False              False
# 6016                 True                      False               True
# 6017                 True                      False              False
# 6018                 True                      False              False
#
#       Owner_Type_Third
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 6014             False
# 6015             False
# 6016             False
# 6017             False
# 6018             False
#
# [6019 rows x 32 columns]

# %%
# drop unwanted columns
dfe=dfe.drop(['Unnamed: 0','Name','Location','Fuel_Type','Transmission','Owner_Type','New_Price'],axis=1)
dfe
# Out:
#       Year  Kilometers_Driven     Mileage   Engine      Power  Seats  Price  \
# 0     2010              72000  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75
# 1     2015              41000  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50
# 2     2011              46000   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50
# 3     2012              87000  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00
# 4     2013              40670   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74
# ...    ...                ...         ...      ...        ...    ...    ...
# 6014  2014              27365   28.4 kmpl  1248 CC     74 bhp    5.0   4.75
# 6015  2015             100000   24.4 kmpl  1120 CC     71 bhp    5.0   4.00
# 6016  2012              55000   14.0 kmpl  2498 CC    112 bhp    8.0   2.90
# 6017  2013              46000   18.9 kmpl   998 CC   67.1 bhp    5.0   2.65
# 6018  2011              47000  25.44 kmpl   936 CC   57.6 bhp    5.0   2.50
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  ...  \
# 0                  False             False                False  ...
# 1                  False             False                False  ...
# 2                  False              True                False  ...
# 3                  False              True                False  ...
# 4                  False             False                 True  ...
# ...                  ...               ...                  ...  ...
# 6014               False             False                False  ...
# 6015               False             False                False  ...
# 6016               False             False                False  ...
# 6017               False             False                False  ...
# 6018               False             False                False  ...
#
#       Location_Mumbai  Location_Pune  Fuel_Type_Diesel  Fuel_Type_Electric  \
# 0                True          False             False               False
# 1               False           True              True               False
# 2               False          False             False               False
# 3               False          False              True               False
# 4               False          False              True               False
# ...               ...            ...               ...                 ...
# 6014            False          False              True               False
# 6015            False          False              True               False
# 6016            False          False              True               False
# 6017            False          False             False               False
# 6018            False          False              True               False
#
#       Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0             False             False                 True
# 1             False             False                 True
# 2             False              True                 True
# 3             False             False                 True
# 4             False             False                False
# ...             ...               ...                  ...
# 6014          False             False                 True
# 6015          False             False                 True
# 6016          False             False                 True
# 6017          False              True                 True
# 6018          False             False                 True
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False               True             False
# ...                         ...                ...               ...
# 6014                      False              False             False
# 6015                      False              False             False
# 6016                      False               True             False
# 6017                      False              False             False
# 6018                      False              False             False
#
# [6019 rows x 25 columns]

# %%
# remove units
dfe['Mileage']=dfe['Mileage'].str.replace('km/kg','')
dfe['Mileage']=dfe['Mileage'].str.replace('kmpl','')
dfe['Engine']=dfe['Engine'].str.replace('CC','')
dfe['Power']=dfe['Power'].str.replace('bhp','')
# null=======0
dfe['Mileage']=dfe['Mileage'].str.replace('null','0')
dfe['Engine']=dfe['Engine'].str.replace('null','0')
dfe['Power']=dfe['Power'].str.replace('null','0')
dfe
# Out:
#       Year  Kilometers_Driven Mileage Engine   Power  Seats  Price  \
# 0     2010              72000   26.6    998   58.16     5.0   1.75
# 1     2015              41000  19.67   1582   126.2     5.0  12.50
# 2     2011              46000   18.2   1199    88.7     5.0   4.50
# 3     2012              87000  20.77   1248   88.76     7.0   6.00
# 4     2013              40670   15.2   1968   140.8     5.0  17.74
# ...    ...                ...     ...    ...     ...    ...    ...
# 6014  2014              27365   28.4   1248      74     5.0   4.75
# 6015  2015             100000   24.4   1120      71     5.0   4.00
# 6016  2012              55000   14.0   2498     112     8.0   2.90
# 6017  2013              46000   18.9    998    67.1     5.0   2.65
# 6018  2011              47000  25.44    936    57.6     5.0   2.50
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  ...  \
# 0                  False             False                False  ...
# 1                  False             False                False  ...
# 2                  False              True                False  ...
# 3                  False              True                False  ...
# 4                  False             False                 True  ...
# ...                  ...               ...                  ...  ...
# 6014               False             False                False  ...
# 6015               False             False                False  ...
# 6016               False             False                False  ...
# 6017               False             False                False  ...
# 6018               False             False                False  ...
#
#       Location_Mumbai  Location_Pune  Fuel_Type_Diesel  Fuel_Type_Electric  \
# 0                True          False             False               False
# 1               False           True              True               False
# 2               False          False             False               False
# 3               False          False              True               False
# 4               False          False              True               False
# ...               ...            ...               ...                 ...
# 6014            False          False              True               False
# 6015            False          False              True               False
# 6016            False          False              True               False
# 6017            False          False             False               False
# 6018            False          False              True               False
#
#       Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0             False             False                 True
# 1             False             False                 True
# 2             False              True                 True
# 3             False             False                 True
# 4             False             False                False
# ...             ...               ...                  ...
# 6014          False             False                 True
# 6015          False             False                 True
# 6016          False             False                 True
# 6017          False              True                 True
# 6018          False             False                 True
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False               True             False
# ...                         ...                ...               ...
# 6014                      False              False             False
# 6015                      False              False             False
# 6016                      False               True             False
# 6017                      False              False             False
# 6018                      False              False             False
#
# [6019 rows x 25 columns]

# %%
dfe.dtypes
# Out:
# Year                           int64
# Kilometers_Driven              int64
# Mileage                       object
# Engine                        object
# Power                         object
# Seats                        float64
# Price                        float64
# Location_Bangalore              bool
# Location_Chennai                bool
# Location_Coimbatore             bool
# Location_Delhi                  bool
# Location_Hyderabad              bool
# Location_Jaipur                 bool
# Location_Kochi                  bool
# Location_Kolkata                bool
# Location_Mumbai                 bool
# Location_Pune                   bool
# Fuel_Type_Diesel                bool
# Fuel_Type_Electric              bool
# Fuel_Type_LPG                   bool
# Fuel_Type_Petrol                bool
# Transmission_Manual             bool
# Owner_Type_Fourth & Above       bool
# Owner_Type_Second               bool
# Owner_Type_Third                bool
# dtype: object

# %%
# data type conversion
dfe['Mileage']=dfe['Mileage'].astype(float)
dfe['Engine']=dfe['Engine'].astype(float)
dfe['Power']=dfe['Power'].astype(float)

# %%
dfe.dtypes
# Out:
# Year                           int64
# Kilometers_Driven              int64
# Mileage                      float64
# Engine                       float64
# Power                        float64
# Seats                        float64
# Price                        float64
# Location_Bangalore              bool
# Location_Chennai                bool
# Location_Coimbatore             bool
# Location_Delhi                  bool
# Location_Hyderabad              bool
# Location_Jaipur                 bool
# Location_Kochi                  bool
# Location_Kolkata                bool
# Location_Mumbai                 bool
# Location_Pune                   bool
# Fuel_Type_Diesel                bool
# Fuel_Type_Electric              bool
# Fuel_Type_LPG                   bool
# Fuel_Type_Petrol                bool
# Transmission_Manual             bool
# Owner_Type_Fourth & Above       bool
# Owner_Type_Second               bool
# Owner_Type_Third                bool
# dtype: object

# %%
# engine,power,mileage====null===>0
import numpy as np
dfe.loc[dfe.Engine==0,'Engine']=np.NaN
dfe.loc[dfe.Power==0,'Power']=np.NaN
dfe.loc[dfe.Mileage==0,'Mileage']=np.NaN    #NaN =missing value

# %%
dfe.isna().sum()
# Out:
# Year                           0
# Kilometers_Driven              0
# Mileage                       70
# Engine                        36
# Power                        143
# Seats                         42
# Price                          0
# Location_Bangalore             0
# Location_Chennai               0
# Location_Coimbatore            0
# Location_Delhi                 0
# Location_Hyderabad             0
# Location_Jaipur                0
# Location_Kochi                 0
# Location_Kolkata               0
# Location_Mumbai                0
# Location_Pune                  0
# Fuel_Type_Diesel               0
# Fuel_Type_Electric             0
# Fuel_Type_LPG                  0
# Fuel_Type_Petrol               0
# Transmission_Manual            0
# Owner_Type_Fourth & Above      0
# Owner_Type_Second              0
# Owner_Type_Third               0
# dtype: int64

# %%
dfe['Engine']=dfe['Engine'].fillna(dfe["Engine"].mean())
dfe['Power']=dfe['Power'].fillna(dfe["Power"].mean())
dfe['Mileage']=dfe['Mileage'].fillna(dfe["Mileage"].mean())
dfe['Seats']=dfe['Seats'].fillna(dfe["Seats"].mean())

# %%
# missing value check
dfe.isna().sum()
# Out:
# Year                         0
# Kilometers_Driven            0
# Mileage                      0
# Engine                       0
# Power                        0
# Seats                        0
# Price                        0
# Location_Bangalore           0
# Location_Chennai             0
# Location_Coimbatore          0
# Location_Delhi               0
# Location_Hyderabad           0
# Location_Jaipur              0
# Location_Kochi               0
# Location_Kolkata             0
# Location_Mumbai              0
# Location_Pune                0
# Fuel_Type_Diesel             0
# Fuel_Type_Electric           0
# Fuel_Type_LPG                0
# Fuel_Type_Petrol             0
# Transmission_Manual          0
# Owner_Type_Fourth & Above    0
# Owner_Type_Second            0
# Owner_Type_Third             0
# dtype: int64

# %%
# sep x and y
x=df.drop(['Price'],axis=1)
x
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price
# 0      998 CC  58.16 bhp    5.0        NaN
# 1     1582 CC  126.2 bhp    5.0        NaN
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh
# 3     1248 CC  88.76 bhp    7.0        NaN
# 4     1968 CC  140.8 bhp    5.0        NaN
# ...       ...        ...    ...        ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh
# 6015  1120 CC     71 bhp    5.0        NaN
# 6016  2498 CC    112 bhp    8.0        NaN
# 6017   998 CC   67.1 bhp    5.0        NaN
# 6018   936 CC   57.6 bhp    5.0        NaN
#
# [6019 rows x 13 columns]

# %%
y=dfe["Price"]
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 6019, dtype: float64

# %%
# convert to DataFrame test data
df2=pd.read_csv('/content/test-data.csv')
df2
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0          Delhi  2014              40929       CNG       Manual      First
# 1     Coimbatore  2013              54493    Petrol       Manual     Second
# 2         Mumbai  2017              34000    Diesel       Manual      First
# 3      Hyderabad  2012             139000    Diesel       Manual      First
# 4         Mumbai  2014              29000    Petrol       Manual      First
# ...          ...   ...                ...       ...          ...        ...
# 1229   Hyderabad  2011              89411    Diesel       Manual      First
# 1230      Mumbai  2015              59000    Petrol    Automatic      First
# 1231     Kolkata  2012              28000    Diesel       Manual      First
# 1232        Pune  2013              52262    Petrol    Automatic      Third
# 1233       Kochi  2014              72443    Diesel    Automatic      First
#
#           Mileage   Engine      Power  Seats   New_Price
# 0     32.26 km/kg   998 CC   58.2 bhp    4.0         NaN
# 1       24.7 kmpl   796 CC   47.3 bhp    5.0         NaN
# 2      13.68 kmpl  2393 CC  147.8 bhp    7.0  25.27 Lakh
# 3      23.59 kmpl  1364 CC   null bhp    5.0         NaN
# 4       18.5 kmpl  1197 CC  82.85 bhp    5.0         NaN
# ...           ...      ...        ...    ...         ...
# 1229   20.54 kmpl  1598 CC  103.6 bhp    5.0         NaN
# 1230   17.21 kmpl  1197 CC  103.6 bhp    5.0         NaN
# 1231   23.08 kmpl  1461 CC   63.1 bhp    5.0         NaN
# 1232    17.2 kmpl  1197 CC  103.6 bhp    5.0         NaN
# 1233    10.0 kmpl  2148 CC    170 bhp    5.0         NaN
#
# [1234 rows x 13 columns]

# %%
df2.head()
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN
# 4  82.85 bhp    5.0         NaN

# %%
df2.tail()
# Out:
#       Unnamed: 0                                               Name  \
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#        Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 1229  Hyderabad  2011              89411    Diesel       Manual      First
# 1230     Mumbai  2015              59000    Petrol    Automatic      First
# 1231    Kolkata  2012              28000    Diesel       Manual      First
# 1232       Pune  2013              52262    Petrol    Automatic      Third
# 1233      Kochi  2014              72443    Diesel    Automatic      First
#
#          Mileage   Engine      Power  Seats New_Price
# 1229  20.54 kmpl  1598 CC  103.6 bhp    5.0       NaN
# 1230  17.21 kmpl  1197 CC  103.6 bhp    5.0       NaN
# 1231  23.08 kmpl  1461 CC   63.1 bhp    5.0       NaN
# 1232   17.2 kmpl  1197 CC  103.6 bhp    5.0       NaN
# 1233   10.0 kmpl  2148 CC    170 bhp    5.0       NaN

# %%
df2.shape
# Out:
# (1234, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
loc=df2['Location'].value_counts()
loc
# Out:
# Location
# Mumbai        159
# Pune          143
# Coimbatore    136
# Hyderabad     134
# Kochi         121
# Kolkata       119
# Delhi         106
# Chennai        97
# Jaipur         86
# Bangalore      82
# Ahmedabad      51
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
location.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('locationcount graph',color='green',fontsize=26)
# Out:
# Text(0.5, 1.0, 'locationcount graph')

# %%
fuel=df2['Fuel_Type'].value_counts()
fuel
# Out:
# Fuel_Type
# Diesel    647
# Petrol    579
# CNG         6
# LPG         2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
fuel.plot(kind='barh',color='red',fontsize=15)
plt.title('fulecount graph ',color='red',fontsize=26)
# Out:
# Text(0.5, 1.0, 'fulecount graph ')

# %%
Transmission=df2['Transmission'].value_counts()
Transmission
# Out:
# Transmission
# Manual       905
# Automatic    329
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
Transmission.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('Transmissionioncount graph',color='green',fontsize=26)
# Out:
# Text(0.5, 1.0, 'Transmissionioncount graph')

# %%
owner=df2['Owner_Type'].value_counts()
owner
# Out:
# Owner_Type
# First             1023
# Second             184
# Third               24
# Fourth & Above       3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
owner.plot(kind='barh',color='red',fontsize=15)
plt.title('ownerecount graph ',color='red',fontsize=26)
# Out:
# Text(0.5, 1.0, 'ownerecount graph ')

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price'],
#       dtype='object')

# %%
df3=pd.get_dummies(df2[['Location','Fuel_Type','Transmission','Owner_Type']],drop_first=True)
df3
# Out:
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 0                  False             False                False
# 1                  False             False                 True
# 2                  False             False                False
# 3                  False             False                False
# 4                  False             False                False
# ...                  ...               ...                  ...
# 1229               False             False                False
# 1230               False             False                False
# 1231               False             False                False
# 1232               False             False                False
# 1233               False             False                False
#
#       Location_Delhi  Location_Hyderabad  Location_Jaipur  Location_Kochi  \
# 0               True               False            False           False
# 1              False               False            False           False
# 2              False               False            False           False
# 3              False                True            False           False
# 4              False               False            False           False
# ...              ...                 ...              ...             ...
# 1229           False                True            False           False
# 1230           False               False            False           False
# 1231           False               False            False           False
# 1232           False               False            False           False
# 1233           False               False            False            True
#
#       Location_Kolkata  Location_Mumbai  Location_Pune  Fuel_Type_Diesel  \
# 0                False            False          False             False
# 1                False            False          False             False
# 2                False             True          False              True
# 3                False            False          False              True
# 4                False             True          False             False
# ...                ...              ...            ...               ...
# 1229             False            False          False              True
# 1230             False             True          False             False
# 1231              True            False          False              True
# 1232             False            False           True             False
# 1233             False            False          False              True
#
#       Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0             False             False                 True
# 1             False              True                 True
# 2             False             False                 True
# 3             False             False                 True
# 4             False              True                 True
# ...             ...               ...                  ...
# 1229          False             False                 True
# 1230          False              True                False
# 1231          False             False                 True
# 1232          False              True                False
# 1233          False             False                False
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False               True             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
# ...                         ...                ...               ...
# 1229                      False              False             False
# 1230                      False              False             False
# 1231                      False              False             False
# 1232                      False              False              True
# 1233                      False              False             False
#
# [1234 rows x 17 columns]

# %%
df2
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0          Delhi  2014              40929       CNG       Manual      First
# 1     Coimbatore  2013              54493    Petrol       Manual     Second
# 2         Mumbai  2017              34000    Diesel       Manual      First
# 3      Hyderabad  2012             139000    Diesel       Manual      First
# 4         Mumbai  2014              29000    Petrol       Manual      First
# ...          ...   ...                ...       ...          ...        ...
# 1229   Hyderabad  2011              89411    Diesel       Manual      First
# 1230      Mumbai  2015              59000    Petrol    Automatic      First
# 1231     Kolkata  2012              28000    Diesel       Manual      First
# 1232        Pune  2013              52262    Petrol    Automatic      Third
# 1233       Kochi  2014              72443    Diesel    Automatic      First
#
#           Mileage   Engine      Power  Seats   New_Price
# 0     32.26 km/kg   998 CC   58.2 bhp    4.0         NaN
# 1       24.7 kmpl   796 CC   47.3 bhp    5.0         NaN
# 2      13.68 kmpl  2393 CC  147.8 bhp    7.0  25.27 Lakh
# 3      23.59 kmpl  1364 CC   null bhp    5.0         NaN
# 4       18.5 kmpl  1197 CC  82.85 bhp    5.0         NaN
# ...           ...      ...        ...    ...         ...
# 1229   20.54 kmpl  1598 CC  103.6 bhp    5.0         NaN
# 1230   17.21 kmpl  1197 CC  103.6 bhp    5.0         NaN
# 1231   23.08 kmpl  1461 CC   63.1 bhp    5.0         NaN
# 1232    17.2 kmpl  1197 CC  103.6 bhp    5.0         NaN
# 1233    10.0 kmpl  2148 CC    170 bhp    5.0         NaN
#
# [1234 rows x 13 columns]

# %%
# concatination dummy and old date frame
dfe2=pd.concat([df2,df3],axis=1)
dfe2
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0          Delhi  2014              40929       CNG       Manual      First
# 1     Coimbatore  2013              54493    Petrol       Manual     Second
# 2         Mumbai  2017              34000    Diesel       Manual      First
# 3      Hyderabad  2012             139000    Diesel       Manual      First
# 4         Mumbai  2014              29000    Petrol       Manual      First
# ...          ...   ...                ...       ...          ...        ...
# 1229   Hyderabad  2011              89411    Diesel       Manual      First
# 1230      Mumbai  2015              59000    Petrol    Automatic      First
# 1231     Kolkata  2012              28000    Diesel       Manual      First
# 1232        Pune  2013              52262    Petrol    Automatic      Third
# 1233       Kochi  2014              72443    Diesel    Automatic      First
#
#           Mileage   Engine  ... Location_Kolkata  Location_Mumbai  \
# 0     32.26 km/kg   998 CC  ...            False            False
# 1       24.7 kmpl   796 CC  ...            False            False
# 2      13.68 kmpl  2393 CC  ...            False             True
# 3      23.59 kmpl  1364 CC  ...            False            False
# 4       18.5 kmpl  1197 CC  ...            False             True
# ...           ...      ...  ...              ...              ...
# 1229   20.54 kmpl  1598 CC  ...            False            False
# 1230   17.21 kmpl  1197 CC  ...            False             True
# 1231   23.08 kmpl  1461 CC  ...             True            False
# 1232    17.2 kmpl  1197 CC  ...            False            False
# 1233    10.0 kmpl  2148 CC  ...            False            False
#
#      Location_Pune  Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol  \
# 0            False             False          False             False
# 1            False             False          False              True
# 2            False              True          False             False
# 3            False              True          False             False
# 4            False             False          False              True
# ...            ...               ...            ...               ...
# 1229         False              True          False             False
# 1230         False             False          False              True
# 1231         False              True          False             False
# 1232          True             False          False              True
# 1233         False              True          False             False
#
#       Transmission_Manual  Owner_Type_Fourth & Above  Owner_Type_Second  \
# 0                    True                      False              False
# 1                    True                      False               True
# 2                    True                      False              False
# 3                    True                      False              False
# 4                    True                      False              False
# ...                   ...                        ...                ...
# 1229                 True                      False              False
# 1230                False                      False              False
# 1231                 True                      False              False
# 1232                False                      False              False
# 1233                False                      False              False
#
#       Owner_Type_Third
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 1229             False
# 1230             False
# 1231             False
# 1232              True
# 1233             False
#
# [1234 rows x 30 columns]

# %%
dfe2.isna().sum()
# Out:
# Unnamed: 0                      0
# Name                            0
# Location                        0
# Year                            0
# Kilometers_Driven               0
# Fuel_Type                       0
# Transmission                    0
# Owner_Type                      0
# Mileage                         0
# Engine                         10
# Power                          10
# Seats                          11
# New_Price                    1052
# Location_Bangalore              0
# Location_Chennai                0
# Location_Coimbatore             0
# Location_Delhi                  0
# Location_Hyderabad              0
# Location_Jaipur                 0
# Location_Kochi                  0
# Location_Kolkata                0
# Location_Mumbai                 0
# Location_Pune                   0
# Fuel_Type_Diesel                0
# Fuel_Type_LPG                   0
# Fuel_Type_Petrol                0
# Transmission_Manual             0
# Owner_Type_Fourth & Above       0
# Owner_Type_Second               0
# Owner_Type_Third                0
# dtype: int64

# %%
#droping dummy and unwanted columns
dfe2.drop(['Name','Unnamed: 0','New_Price','Location','Fuel_Type','Transmission','Owner_Type'],axis=1,inplace=True)
dfe2
# Out:
#       Year  Kilometers_Driven      Mileage   Engine      Power  Seats  \
# 0     2014              40929  32.26 km/kg   998 CC   58.2 bhp    4.0
# 1     2013              54493    24.7 kmpl   796 CC   47.3 bhp    5.0
# 2     2017              34000   13.68 kmpl  2393 CC  147.8 bhp    7.0
# 3     2012             139000   23.59 kmpl  1364 CC   null bhp    5.0
# 4     2014              29000    18.5 kmpl  1197 CC  82.85 bhp    5.0
# ...    ...                ...          ...      ...        ...    ...
# 1229  2011              89411   20.54 kmpl  1598 CC  103.6 bhp    5.0
# 1230  2015              59000   17.21 kmpl  1197 CC  103.6 bhp    5.0
# 1231  2012              28000   23.08 kmpl  1461 CC   63.1 bhp    5.0
# 1232  2013              52262    17.2 kmpl  1197 CC  103.6 bhp    5.0
# 1233  2014              72443    10.0 kmpl  2148 CC    170 bhp    5.0
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 0                  False             False                False
# 1                  False             False                 True
# 2                  False             False                False
# 3                  False             False                False
# 4                  False             False                False
# ...                  ...               ...                  ...
# 1229               False             False                False
# 1230               False             False                False
# 1231               False             False                False
# 1232               False             False                False
# 1233               False             False                False
#
#       Location_Delhi  ...  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 0               True  ...             False            False          False
# 1              False  ...             False            False          False
# 2              False  ...             False             True          False
# 3              False  ...             False            False          False
# 4              False  ...             False             True          False
# ...              ...  ...               ...              ...            ...
# 1229           False  ...             False            False          False
# 1230           False  ...             False             True          False
# 1231           False  ...              True            False          False
# 1232           False  ...             False            False           True
# 1233           False  ...             False            False          False
#
#       Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0                False          False             False                 True
# 1                False          False              True                 True
# 2                 True          False             False                 True
# 3                 True          False             False                 True
# 4                False          False              True                 True
# ...                ...            ...               ...                  ...
# 1229              True          False             False                 True
# 1230             False          False              True                False
# 1231              True          False             False                 True
# 1232             False          False              True                False
# 1233              True          False             False                False
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False               True             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
# ...                         ...                ...               ...
# 1229                      False              False             False
# 1230                      False              False             False
# 1231                      False              False             False
# 1232                      False              False              True
# 1233                      False              False             False
#
# [1234 rows x 23 columns]

# %%
# string replace opeeration
dfe2['Mileage']=dfe2['Mileage'].str.replace('km/kg','')
dfe2['Mileage']=dfe2['Mileage'].str.replace('kmpl','')
dfe2['Engine']=dfe2['Engine'].str.replace('CC','')
dfe2['Power']=dfe2['Power'].str.replace('bhp','')
dfe2['Mileage']=dfe2['Mileage'].str.replace('null','0')
dfe2['Engine']=dfe2['Engine'].str.replace('null','0')
dfe2['Power']=dfe2['Power'].str.replace('null','0')
dfe2
# Out:
#       Year  Kilometers_Driven Mileage Engine   Power  Seats  \
# 0     2014              40929  32.26    998    58.2     4.0
# 1     2013              54493   24.7    796    47.3     5.0
# 2     2017              34000  13.68   2393   147.8     7.0
# 3     2012             139000  23.59   1364       0     5.0
# 4     2014              29000   18.5   1197   82.85     5.0
# ...    ...                ...     ...    ...     ...    ...
# 1229  2011              89411  20.54   1598   103.6     5.0
# 1230  2015              59000  17.21   1197   103.6     5.0
# 1231  2012              28000  23.08   1461    63.1     5.0
# 1232  2013              52262   17.2   1197   103.6     5.0
# 1233  2014              72443   10.0   2148     170     5.0
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 0                  False             False                False
# 1                  False             False                 True
# 2                  False             False                False
# 3                  False             False                False
# 4                  False             False                False
# ...                  ...               ...                  ...
# 1229               False             False                False
# 1230               False             False                False
# 1231               False             False                False
# 1232               False             False                False
# 1233               False             False                False
#
#       Location_Delhi  ...  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 0               True  ...             False            False          False
# 1              False  ...             False            False          False
# 2              False  ...             False             True          False
# 3              False  ...             False            False          False
# 4              False  ...             False             True          False
# ...              ...  ...               ...              ...            ...
# 1229           False  ...             False            False          False
# 1230           False  ...             False             True          False
# 1231           False  ...              True            False          False
# 1232           False  ...             False            False           True
# 1233           False  ...             False            False          False
#
#       Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0                False          False             False                 True
# 1                False          False              True                 True
# 2                 True          False             False                 True
# 3                 True          False             False                 True
# 4                False          False              True                 True
# ...                ...            ...               ...                  ...
# 1229              True          False             False                 True
# 1230             False          False              True                False
# 1231              True          False             False                 True
# 1232             False          False              True                False
# 1233              True          False             False                False
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False               True             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
# ...                         ...                ...               ...
# 1229                      False              False             False
# 1230                      False              False             False
# 1231                      False              False             False
# 1232                      False              False              True
# 1233                      False              False             False
#
# [1234 rows x 23 columns]

# %%
dfe2['Mileage']=dfe2['Mileage'].astype(float)
dfe2['Engine']=dfe2['Engine'].astype(float)
dfe2['Power']=dfe2['Power'].astype(float)

# %%
dfe2.dtypes
# Out:
# Year                           int64
# Kilometers_Driven              int64
# Mileage                      float64
# Engine                       float64
# Power                        float64
# Seats                        float64
# Location_Bangalore              bool
# Location_Chennai                bool
# Location_Coimbatore             bool
# Location_Delhi                  bool
# Location_Hyderabad              bool
# Location_Jaipur                 bool
# Location_Kochi                  bool
# Location_Kolkata                bool
# Location_Mumbai                 bool
# Location_Pune                   bool
# Fuel_Type_Diesel                bool
# Fuel_Type_LPG                   bool
# Fuel_Type_Petrol                bool
# Transmission_Manual             bool
# Owner_Type_Fourth & Above       bool
# Owner_Type_Second               bool
# Owner_Type_Third                bool
# dtype: object

# %%
import numpy as np
dfe2.loc[dfe2.Engine==0,'Engine']=np.NaN
dfe2.loc[dfe2.Power==0,'Power']=np.NaN
dfe2.loc[dfe2.Mileage==0,'Mileage']=np.NaN

# %%
dfe2.isna().sum()
# Out:
# Year                          0
# Kilometers_Driven             0
# Mileage                      13
# Engine                       10
# Power                        32
# Seats                        11
# Location_Bangalore            0
# Location_Chennai              0
# Location_Coimbatore           0
# Location_Delhi                0
# Location_Hyderabad            0
# Location_Jaipur               0
# Location_Kochi                0
# Location_Kolkata              0
# Location_Mumbai               0
# Location_Pune                 0
# Fuel_Type_Diesel              0
# Fuel_Type_LPG                 0
# Fuel_Type_Petrol              0
# Transmission_Manual           0
# Owner_Type_Fourth & Above     0
# Owner_Type_Second             0
# Owner_Type_Third              0
# dtype: int64

# %%
dfe2['Engine']=dfe2['Engine'].fillna(dfe2['Engine'].mean())
dfe2['Power']=dfe2['Power'].fillna(dfe2['Power'].mean())
dfe2['Mileage']=dfe2['Mileage'].fillna(dfe2['Mileage'].mean())
dfe2['Seats']=dfe2['Seats'].fillna(dfe2['Seats'].mode()[0])

# %%
dfe2.isna().sum()
# Out:
# Year                         0
# Kilometers_Driven            0
# Mileage                      0
# Engine                       0
# Power                        0
# Seats                        0
# Location_Bangalore           0
# Location_Chennai             0
# Location_Coimbatore          0
# Location_Delhi               0
# Location_Hyderabad           0
# Location_Jaipur              0
# Location_Kochi               0
# Location_Kolkata             0
# Location_Mumbai              0
# Location_Pune                0
# Fuel_Type_Diesel             0
# Fuel_Type_LPG                0
# Fuel_Type_Petrol             0
# Transmission_Manual          0
# Owner_Type_Fourth & Above    0
# Owner_Type_Second            0
# Owner_Type_Third             0
# dtype: int64

# %%
# sep x_test
x_test=dfe2
x_test
# Out:
#       Year  Kilometers_Driven  Mileage  Engine      Power  Seats  \
# 0     2014              40929    32.26   998.0   58.20000    4.0
# 1     2013              54493    24.70   796.0   47.30000    5.0
# 2     2017              34000    13.68  2393.0  147.80000    7.0
# 3     2012             139000    23.59  1364.0  110.38042    5.0
# 4     2014              29000    18.50  1197.0   82.85000    5.0
# ...    ...                ...      ...     ...        ...    ...
# 1229  2011              89411    20.54  1598.0  103.60000    5.0
# 1230  2015              59000    17.21  1197.0  103.60000    5.0
# 1231  2012              28000    23.08  1461.0   63.10000    5.0
# 1232  2013              52262    17.20  1197.0  103.60000    5.0
# 1233  2014              72443    10.00  2148.0  170.00000    5.0
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 0                  False             False                False
# 1                  False             False                 True
# 2                  False             False                False
# 3                  False             False                False
# 4                  False             False                False
# ...                  ...               ...                  ...
# 1229               False             False                False
# 1230               False             False                False
# 1231               False             False                False
# 1232               False             False                False
# 1233               False             False                False
#
#       Location_Delhi  ...  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 0               True  ...             False            False          False
# 1              False  ...             False            False          False
# 2              False  ...             False             True          False
# 3              False  ...             False            False          False
# 4              False  ...             False             True          False
# ...              ...  ...               ...              ...            ...
# 1229           False  ...             False            False          False
# 1230           False  ...             False             True          False
# 1231           False  ...              True            False          False
# 1232           False  ...             False            False           True
# 1233           False  ...             False            False          False
#
#       Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0                False          False             False                 True
# 1                False          False              True                 True
# 2                 True          False             False                 True
# 3                 True          False             False                 True
# 4                False          False              True                 True
# ...                ...            ...               ...                  ...
# 1229              True          False             False                 True
# 1230             False          False              True                False
# 1231              True          False             False                 True
# 1232             False          False              True                False
# 1233              True          False             False                False
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False               True             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
# ...                         ...                ...               ...
# 1229                      False              False             False
# 1230                      False              False             False
# 1231                      False              False             False
# 1232                      False              False              True
# 1233                      False              False             False
#
# [1234 rows x 23 columns]

# %%
x_test.head()
# Out:
#    Year  Kilometers_Driven  Mileage  Engine      Power  Seats  \
# 0  2014              40929    32.26   998.0   58.20000    4.0
# 1  2013              54493    24.70   796.0   47.30000    5.0
# 2  2017              34000    13.68  2393.0  147.80000    7.0
# 3  2012             139000    23.59  1364.0  110.38042    5.0
# 4  2014              29000    18.50  1197.0   82.85000    5.0
#
#    Location_Bangalore  Location_Chennai  Location_Coimbatore  Location_Delhi  \
# 0               False             False                False            True
# 1               False             False                 True           False
# 2               False             False                False           False
# 3               False             False                False           False
# 4               False             False                False           False
#
#    ...  Location_Kolkata  Location_Mumbai  Location_Pune  Fuel_Type_Diesel  \
# 0  ...             False            False          False             False
# 1  ...             False            False          False             False
# 2  ...             False             True          False              True
# 3  ...             False            False          False              True
# 4  ...             False             True          False             False
#
#    Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0          False             False                 True
# 1          False              True                 True
# 2          False             False                 True
# 3          False             False                 True
# 4          False              True                 True
#
#    Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                      False              False             False
# 1                      False               True             False
# 2                      False              False             False
# 3                      False              False             False
# 4                      False              False             False
#
# [5 rows x 23 columns]

# %%
x_test.tail()
# Out:
#       Year  Kilometers_Driven  Mileage  Engine  Power  Seats  \
# 1229  2011              89411    20.54  1598.0  103.6    5.0
# 1230  2015              59000    17.21  1197.0  103.6    5.0
# 1231  2012              28000    23.08  1461.0   63.1    5.0
# 1232  2013              52262    17.20  1197.0  103.6    5.0
# 1233  2014              72443    10.00  2148.0  170.0    5.0
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 1229               False             False                False
# 1230               False             False                False
# 1231               False             False                False
# 1232               False             False                False
# 1233               False             False                False
#
#       Location_Delhi  ...  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 1229           False  ...             False            False          False
# 1230           False  ...             False             True          False
# 1231           False  ...              True            False          False
# 1232           False  ...             False            False           True
# 1233           False  ...             False            False          False
#
#       Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 1229              True          False             False                 True
# 1230             False          False              True                False
# 1231              True          False             False                 True
# 1232             False          False              True                False
# 1233              True          False             False                False
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 1229                      False              False             False
# 1230                      False              False             False
# 1231                      False              False             False
# 1232                      False              False              True
# 1233                      False              False             False
#
# [5 rows x 23 columns]

# %%
# fst 5 obser
x_test.head()
# Out:
#    Year  Kilometers_Driven  Mileage  Engine      Power  Seats  \
# 0  2014              40929    32.26   998.0   58.20000    4.0
# 1  2013              54493    24.70   796.0   47.30000    5.0
# 2  2017              34000    13.68  2393.0  147.80000    7.0
# 3  2012             139000    23.59  1364.0  110.38042    5.0
# 4  2014              29000    18.50  1197.0   82.85000    5.0
#
#    Location_Bangalore  Location_Chennai  Location_Coimbatore  Location_Delhi  \
# 0               False             False                False            True
# 1               False             False                 True           False
# 2               False             False                False           False
# 3               False             False                False           False
# 4               False             False                False           False
#
#    ...  Location_Kolkata  Location_Mumbai  Location_Pune  Fuel_Type_Diesel  \
# 0  ...             False            False          False             False
# 1  ...             False            False          False             False
# 2  ...             False             True          False              True
# 3  ...             False            False          False              True
# 4  ...             False             True          False             False
#
#    Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0          False             False                 True
# 1          False              True                 True
# 2          False             False                 True
# 3          False             False                 True
# 4          False              True                 True
#
#    Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                      False              False             False
# 1                      False               True             False
# 2                      False              False             False
# 3                      False              False             False
# 4                      False              False             False
#
# [5 rows x 23 columns]

# %%
# drop fuel type electric col to make training testing same no of columns
x=dfe.drop(['Fuel_Type_Electric','Price'],axis=1)
x
# Out:
#       Year  Kilometers_Driven  Mileage  Engine   Power  Seats  \
# 0     2010              72000    26.60   998.0   58.16    5.0
# 1     2015              41000    19.67  1582.0  126.20    5.0
# 2     2011              46000    18.20  1199.0   88.70    5.0
# 3     2012              87000    20.77  1248.0   88.76    7.0
# 4     2013              40670    15.20  1968.0  140.80    5.0
# ...    ...                ...      ...     ...     ...    ...
# 6014  2014              27365    28.40  1248.0   74.00    5.0
# 6015  2015             100000    24.40  1120.0   71.00    5.0
# 6016  2012              55000    14.00  2498.0  112.00    8.0
# 6017  2013              46000    18.90   998.0   67.10    5.0
# 6018  2011              47000    25.44   936.0   57.60    5.0
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  \
# 0                  False             False                False
# 1                  False             False                False
# 2                  False              True                False
# 3                  False              True                False
# 4                  False             False                 True
# ...                  ...               ...                  ...
# 6014               False             False                False
# 6015               False             False                False
# 6016               False             False                False
# 6017               False             False                False
# 6018               False             False                False
#
#       Location_Delhi  ...  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 0              False  ...             False             True          False
# 1              False  ...             False            False           True
# 2              False  ...             False            False          False
# 3              False  ...             False            False          False
# 4              False  ...             False            False          False
# ...              ...  ...               ...              ...            ...
# 6014            True  ...             False            False          False
# 6015           False  ...             False            False          False
# 6016           False  ...             False            False          False
# 6017           False  ...              True            False          False
# 6018           False  ...             False            False          False
#
#       Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol  Transmission_Manual  \
# 0                False          False             False                 True
# 1                 True          False             False                 True
# 2                False          False              True                 True
# 3                 True          False             False                 True
# 4                 True          False             False                False
# ...                ...            ...               ...                  ...
# 6014              True          False             False                 True
# 6015              True          False             False                 True
# 6016              True          False             False                 True
# 6017             False          False              True                 True
# 6018              True          False             False                 True
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False               True             False
# ...                         ...                ...               ...
# 6014                      False              False             False
# 6015                      False              False             False
# 6016                      False               True             False
# 6017                      False              False             False
# 6018                      False              False             False
#
# [6019 rows x 23 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 2.8736482 , -1.28345868, 16.1083875 , ...,  0.13667284,
#         9.27855283, 21.47308628])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_poly=poly.fit_transform(x)
x_poly
# Out:
# array([[1.000e+00, 2.010e+03, 7.200e+04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.015e+03, 4.100e+04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.011e+03, 4.600e+04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        ...,
#        [1.000e+00, 2.012e+03, 5.500e+04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.013e+03, 4.600e+04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.011e+03, 4.700e+04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]])

# %%
x_poly.shape
# Out:
# (6019, 2600)

# %%
y.shape
# Out:
# (6019,)

# %%
poly.fit(x_poly,y)
from sklearn.linear_model import LinearRegression
model2=LinearRegression()
model2.fit(x_poly,y)
y_poly=model2.predict(x_poly)
y_poly
# Out:
# array([ 2.03020003, 10.18085091,  3.23833358, ...,  1.43936667,
#         3.37700472,  2.69863846])

# %%
y_poly
# Out:
# array([ 2.03020003, 10.18085091,  3.23833358, ...,  1.43936667,
#         3.37700472,  2.69863846])

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('error is ',mean_absolute_percentage_error(y,y_poly))
# Out:
# error is  0.3222300747004856

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print('MAE is :',mean_absolute_error(y,y_poly))
# Out:
# MAE is : 2.1340344950509924

# %%
print('MSE is',mean_squared_error(y,y_poly))
# Out:
# MSE is 15.926835148377084

# %%
print('Root mean squared error :',np.sqrt(mean_squared_error(y,y_poly)))
# Out:
# Root mean squared error : 3.990843914308988

# %%
print('r2 score is',r2_score(y,y_poly))
# Out:
# r2 score is 0.8727367046997142
